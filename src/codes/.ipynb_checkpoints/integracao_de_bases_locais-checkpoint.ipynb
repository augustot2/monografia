# %% [markdown]
# # Implementação
#  Resolver a integral:
# \begin{equation}
# \int_\Omega \phi_i(x) \phi_i(x) \partial x =
#  \int_{-1}^{1} \phi_i(\epsilon) \phi_i(\epsilon) J\partial \epsilon \\
#  = \sum^Q_{q=1} \phi_i(\epsilon_q) \phi_i(\epsilon_q) w_q J_q
# \end{equation}

# %%
using Jacobi
using PyPlot

# %%
using LaTeXStrings

# %%
#intervalo
x = linspace(-1,1,101)
function ϕ0(x)
    if(x<=1.0 && x >= -1.0)
        ϕ0 = (1-x)/2
    else
        ϕ0 = 0
    end
    return ϕ0
end
function ϕ1(x)
    if(x<=1.0 && x >= -1.0)
        ϕ1 = (1+x)/2
    else
        ϕ1 = 0
    end
    return ϕ1
end

function ψ(p,E)
    if(p == 1)
     return  (1-E)/2
    end 
    if(p == 2)
     return  (1+E)/2
    end
     return  (1-E)*(1+E)/4 * jacobi(E, p-3, 1, 1)
end
# Out:
# ψ (generic function with 1 method)

# %%
x = linspace(-1,1,101)
p1 = [ψ(1,E) for E in x ]
p2 = [ψ(2,E) for E in x ]
p3 = [ψ(3,E) for E in x ]
p4 = [ψ(5,E) for E in x ]
# Out:
# 101-element Array{Any,1}:
#  0.0
#  0.0282299
#  0.0530376
#  0.0745979
#  0.0930816
#  0.108656
#  0.121486
#  0.13173
#  0.139546
#  0.145086
#  0.1485
#  0.149934
#  0.14953
#  ⋮
#  0.149934
#  0.1485
#  0.145086
#  0.139546
#  0.13173
#  0.121486
#  0.108656
#  0.0930816
#  0.0745979
#  0.0530376
#  0.0282299
#  0.0

# %%
for i in 1:5
    plot(x,[ψ(i,E) for E in x ], label = LaTeXString("\$ \\phi_{$i} \$"))
    legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f43ff8d3510>)

# %%
#legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
Q = 5
I = 2*Q - 1
ϕ = zeros(I,Q)
ξ = zgj(Q)
w = wgj(ξ,0.,0.)
for i in 1:I
    for j in 1:Q
        ϕ[i,j] = ψ(i,ξ[j])
    end
end
for i in 1:Q
    plot(ξ,ϕ[i,:]')
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f43ff77b3d0>)

# %%
M = zeros(I,I)
for i in 1:I
    for j in i:I
       m= 0.0
        for q in 1:Q
            m = m + ϕ[i,q]*ϕ[j,q]*w[q]
        end
        M[i,j] = m
        M[j,i] = m
    end
end
M
# Out:
# 9x9 Array{Float64,2}:
#   0.666667      0.333333      0.166667     …  -1.0842e-18  -3.05745e-17
#   0.333333      0.666667      0.166667         0.0         -3.1225e-17
#   0.166667      0.166667      0.0666667       -2.1684e-19  -0.00859788
#  -0.0666667     0.0666667     5.42101e-19     -0.00907029   1.0842e-19
#   3.81639e-17   3.81639e-17  -0.0142857        0.0          0.0202271
#  -3.27429e-17   3.1225e-17   -4.33681e-19  …   0.0100781    0.0
#   2.88398e-17   3.1225e-17    9.97466e-18     -2.1684e-19  -0.0178357
#  -1.0842e-18    0.0          -2.1684e-19       0.00719865   0.0
#  -3.05745e-17  -3.1225e-17   -0.00859788       0.0          0.0148986

# %% [markdown]
# # Verificando M
#
# \begin{align}
#   u &= f \\
#  \int_\Omega u \partial x &= \int_\Omega f \partial x \\
#  \int_\Omega v\ u\ \partial x &= \int_\Omega v\ f\ \partial x \\
#  \sum_{q=1}^Q \hat{u_i} \int_\Omega \phi_i(x) \phi_k(x) \partial x &= \sum^Q_{q=1} f(\xi_q)\ \phi_k(\xi_q)\ w_q \\
#  M\ \hat{u} &= F_r
# \end{align}

# %% [markdown]
# \begin{align}
#  u(x) &= \sum^{Q}_{q=1} \hat{u_i} \phi_i(x) \\
#  u    &= \phi \hat{u}
# \end{align}

# %%
#resolve A*X = B
function solver_beta(A,B,nb)
  Abb = A[1:nb,1:nb]
  Abi = A[1:nb,(nb+1):end]
  Aii = A[(nb+1):end,(nb+1):end]
  Aib = A[(nb+1):end,1:nb]
  #########################
  #                       #
  #  |Abb Abi| |xb| = |Bb|#
  #  |Aib Aii| |xi|   |Bi|#
  #########################

  Bi = B[(nb+1):end]
  Bb = B[1:nb]

  Xb = inv(Abb - Abi*inv(Aii)*Aib)* (Bb - Abi*inv(Aii)*Bi)
  Xi = inv(Aii)*Bi - inv(Aii)*transpose(Abi)*Xb

  X = [Xb;Xi]
end
# Out:
# solver_beta (generic function with 1 method)

# %%
fun(x) = sin(pi*x)

#legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
Q = 17
I = 15
ϕ = zeros(Q,I)
ξ = zgj(Q)
w = wgj(ξ,0.,0.)
for i in 1:I
    for j in 1:Q
        ϕ[j,i] = ψ(i,ξ[j])
    end
end

ϕ
# Out:
# 17x15 Array{Float64,2}:
#  0.995288    0.00471226  0.00469006  …  -0.0381335     0.0384574
#  0.975338    0.0246622   0.024054        0.00640386   -0.0236833
#  0.94012     0.0598804   0.0562948       0.0555567    -0.0243305
#  0.890757    0.109243    0.097309       -0.0844933     0.0730984
#  0.828836    0.171164    0.141867        0.0434854    -0.0883601
#  0.756345    0.243655    0.184287    …   0.0417516     0.0550787
#  0.675616    0.324384    0.219159       -0.102095      0.0123531
#  0.589242    0.410758    0.242036        0.0846051    -0.0778273
#  0.5         0.5         0.25            8.14618e-36   0.104736
#  0.410758    0.589242    0.242036       -0.0846051    -0.0778273
#  0.324384    0.675616    0.219159    …   0.102095      0.0123531
#  0.243655    0.756345    0.184287       -0.0417516     0.0550787
#  0.171164    0.828836    0.141867       -0.0434854    -0.0883601
#  0.109243    0.890757    0.097309        0.0844933     0.0730984
#  0.0598804   0.94012     0.0562948      -0.0555567    -0.0243305
#  0.0246622   0.975338    0.024054    …  -0.00640386   -0.0236833
#  0.00471226  0.995288    0.00469006      0.0381335     0.0384574

# %%
M = zeros(I,I)
for i in 1:I
    for j in i:I
       m= 0.0
        for q in 1:Q
            m = m + ϕ[q,i]*ϕ[q,j]*w[q]
        end
        M[i,j] = m
        M[j,i] = m
    end
end
M
# Out:
# 15x15 Array{Float64,2}:
#   0.666667      0.333333      0.166667     …  -2.57159e-18   5.1398e-18
#   0.333333      0.666667      0.166667        -1.55041e-17   4.22839e-18
#   0.166667      0.166667      0.0666667       -5.02121e-18   4.36984e-18
#  -0.0666667     0.0666667     5.47543e-18     -6.48827e-19  -3.57448e-19
#  -3.02831e-17  -3.71339e-17  -0.0142857        3.45928e-18   2.01933e-18
#   1.12105e-17  -3.46403e-17  -6.16555e-18  …  -2.73761e-18   1.01983e-18
#  -3.13021e-17  -2.48282e-17  -3.88873e-18     -1.64324e-18  -2.98833e-18
#   1.29117e-17   6.72205e-18   5.45659e-18      3.7405e-18   -4.40457e-19
#   1.52673e-17   1.27936e-17   7.27262e-18      6.91179e-19   1.2265e-18
#  -6.96558e-18  -9.6494e-18   -5.99657e-18     -4.40457e-20   3.89635e-19
#  -2.0865e-17   -2.10335e-17  -3.95903e-18  …   1.76183e-19  -1.54499e-18
#   3.06601e-17  -1.00831e-17   5.20671e-18     -0.00496894   -4.47233e-19
#  -2.41277e-17  -2.49366e-17  -4.2953e-18      -5.0822e-19   -0.00460548
#  -2.57159e-18  -1.55041e-17  -5.02121e-18      0.00927536    7.99599e-19
#   5.1398e-18    4.22839e-18   4.36984e-18      7.99599e-19   0.00863346

# %%
fr = zeros(I)
for i in 1:I
    temp = 0.0
    for q in 1:Q
        temp = temp + fun(ξ[q])*ϕ[q,i]*w[q]
    end
    fr[i]= temp
end
fr
# Out:
# 15-element Array{Float64,1}:
#  -0.31831
#   0.31831
#   1.3752e-17
#   0.193509
#  -1.44233e-17
#  -0.0823994
#   1.66967e-17
#   0.00971303
#  -4.6824e-18
#  -0.000539007
#   2.34459e-18
#   1.7461e-5
#   1.257e-18
#  -3.71532e-7
#  -2.23956e-18

# %%
uh = solver_beta(M,fr,0)
# Out:
# 15-element Array{Float64,1}:
#  -3.94518e-9
#   3.94518e-9
#   1.6565e-14
#   4.77465
#  -6.85776e-15
#  -0.914905
#  -4.86023e-15
#   0.0692349
#  -6.21389e-15
#  -0.00282615
#   1.20666e-14
#   7.23635e-5
#  -2.86308e-15
#  -1.28966e-6
#  -2.58062e-15

# %%
uq = ϕ*uh
# Out:
# 17-element Array{Float64,1}:
#  -0.0296037
#  -0.154338
#  -0.367426
#  -0.633752
#  -0.879808
#  -0.999205
#  -0.892757
#  -0.5318
#   4.95073e-15
#   0.5318
#   0.892757
#   0.999205
#   0.879808
#   0.633752
#   0.367426
#   0.154338
#   0.0296037

# %%
ue = [fun(i) for i in ξ] 
erro = uq - ue
plot(ξ,uq,"-s",label= "aprox")
plot(ξ,ue,label="exata")
legend()

maximum(erro)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f43ffb1a5d0>)
# 9.963285751979356e-10
