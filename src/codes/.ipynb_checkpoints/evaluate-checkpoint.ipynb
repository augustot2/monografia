# %%
using Jacobi
using PyPlot

# %%
#resolve A*X = B
function solver_beta(A,B,nb)
  Abb = A[1:nb,1:nb]
  Abi = A[1:nb,(nb+1):end]
  Aii = A[(nb+1):end,(nb+1):end]
  Aib = A[(nb+1):end,1:nb]
  #########################
  #                       #
  #  |Abb Abi| |xb| = |Bb|#
  #  |Aib Aii| |xi|   |Bi|#
  #########################

  Bi = B[(nb+1):end]
  Bb = B[1:nb]

  Xb = inv(Abb - Abi*inv(Aii)*Aib)* (Bb - Abi*inv(Aii)*Bi)
  Xi = inv(Aii)*Bi - inv(Aii)*transpose(Abi)*Xb

  X = [Xb;Xi]
end
# Out:
# solver_beta (generic function with 1 method)

# %%
function evaluate(Q,M,fun)
    function ψ(p,E)
        if(p == 1)
         return  (1-E)/2
        end 
        if(p == 2)
         return  (1+E)/2
        end
         return  (1-E)*(1+E)/4 * jacobi(E, p-3, 1, 1)
    end    
    ϕ = zeros(Q,M)
    ξ = zgj(Q)
    w = wgj(ξ,0.,0.)
    for i in 1:M
        for j in 1:Q
            ϕ[j,i] = ψ(i,ξ[j])
        end
    end
    
    L = zeros(M,M)
    for i in 1:M
        for j in 1:M
           m= 0.0
            for q in 1:Q
                m = m + ϕ[q,i]*ϕ[q,j]*w[q]
            end
            L[i,j] = m
            L[j,i] = m
        end
    end
    fr = zeros(M)
    for i in 1:M
        temp = 0.0
        for q in 1:Q
            temp = temp + fun(ξ[q])*ϕ[q,i]*w[q]
        end
        fr[i]= temp
    end
    uh = solver_beta(L,fr,0)
    uq = ϕ*uh
    return uq
end
# Out:
# evaluate (generic function with 1 method)

# %%
Q = 17
I=  10
for i in 1:I
    for q in 1:Q
    uq = evaluate(q,i,fun)
    ξ = zgj(q)
    f = fun(zgj(q))
    plot(ξ,f,label="exata")
    plot(ξ,uq,label="aproximada")
    legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    maximum(uq - f)
    end
end
# Out:
# LoadError: UndefVarError: fun not defined
# while loading In[4], in expression starting on line 3
#
#  [inlined code] from In[4]:5
#  in anonymous at no file:0

# %%
Q = 17
I=  10
fun(x) = sin(2*pi*x)
for i in 10
    for q in 8:16
        uq = evaluate(q,i,fun)
        ξ = zgj(q)
        f = fun(zgj(q))
        maximum(uq - f)
        plot(ξ,f,label= "$q")
        legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    end
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f841744bc90>)

# %% [markdown]
# # Jacobi

# %%
function ψj(p,E)
    if(p == 1)
     return  (1-E)/2
    end 
    if(p == 2)
     return  (1+E)/2
    end
     return  (1-E)*(1+E)/4 * jacobi(E, p-3, 1, 1)
end
# Out:
# ψj (generic function with 1 method)

# %% [markdown]
# # Legendre

# %%
function ψl(p,E)
    if(p == 1)
     return  (1-E)/2
    end 
    if(p == 2)
     return  (1+E)/2
    end
     return  (1-E)*(1+E)/4 *legendre(E, p-3)
end
# Out:
# ψl (generic function with 1 method)
