# %%
using PyPlot

# %%
phi1(x,e) = (x - e[1])/(e[2] - e[1])  
phi2(x,e) = (e[2] - x )/(e[2] - e[1])
# Out:
# phi2 (generic function with 1 method)

# %%
e1 = [0,1/3]
e2 = [1/3,2/3]
e3 = [2/3,1]
# Out:
# 2-element Array{Float64,1}:
#  0.666667
#  1.0

# %%
phi1(x,e1)
# Out:
# 34-element Array{Float64,1}:
#  0.0
#  0.03
#  0.06
#  0.09
#  0.12
#  0.15
#  0.18
#  0.21
#  0.24
#  0.27
#  0.3
#  0.33
#  0.36
#  ⋮
#  0.66
#  0.69
#  0.72
#  0.75
#  0.78
#  0.81
#  0.84
#  0.87
#  0.9
#  0.93
#  0.96
#  0.99

# %%
subplot(2,1,1)
x = collect(e1[1]:0.01:e1[2])
y = phi1(x,e1)
plot(x,y,color = "red")


x = collect(e1[1]:0.01:e1[2])
y = phi2(x,e1)
plot(x,y,color =  "red")




x = collect(e2[1]:0.01:e2[2])
y = phi1(x,e2)
plot(x,y,color = "green")


x = collect(e2[1]:0.01:e2[2])
y = phi2(x,e2)
plot(x,y,color = "green")



x = collect(e3[1]:0.01:e3[2])
y = phi1(x,e3)
plot(x,y,color = "yellow")


x = collect(e3[1]:0.01:e3[2])
y = phi2(x,e3)
plot(x,y,color = "yellow")

#xlim([0,1])
[axvline(x,color = "black") for x in linspace(0,1,4)]
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb135235350>)
# 4-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb132a22750>
#  PyObject <matplotlib.lines.Line2D object at 0x7fb132d49d90>
#  PyObject <matplotlib.lines.Line2D object at 0x7fb132d2be10>
#  PyObject <matplotlib.lines.Line2D object at 0x7fb132d91e50>

# %%
subplot(2,1,1)
x = collect(e1[1]:0.01:e1[2])
y = phi2(x,e1)
plot(x,y,color = "olive")


x = collect(e1[1]:0.01:e1[2])
y = phi1(x,e1)
plot(x,y,color =  "red")




x = collect(e2[1]:0.01:e2[2])
y = phi2(x,e2)
plot(x,y,color = "red")


x = collect(e2[1]:0.01:e2[2])
y = phi1(x,e2)
plot(x,y,color = "green")



x = collect(e3[1]:0.01:e3[2])
y = phi2(x,e3)
plot(x,y,color = "green")


x = collect(e3[1]:0.01:e3[2])
y = phi1(x,e3)
plot(x,y,color = "yellow")

#xlim([-0.1,1.1])
ylim([-0.1,1.1])
axhline(0,color="black")
#[axvline(x,color = "black") for x in linspace(0,1,4)]
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb135235890>)
# PyObject <matplotlib.lines.Line2D object at 0x7fb1329870d0>

# %%
x1 = linspace(e1[1],e1[2],100)
x2 = linspace(e2[1],e2[2],100)
x3 = linspace(e3[1],e3[2],100)
# Out:
# linspace(0.6666666666666666,1.0,100)

# %%
f1(x) = 3*x -1
f2(x) = 3 - 3*x
# Out:
# f2 (generic function with 1 method)

# %%
plot(x2,f1(x2))
plot(x3,f2(x3))#
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb132ae9810>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb132972610>

# %%
f3(x) = 3*x  -2
plot(x3,f3(x3))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb1329ea4d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb1327e6450>
