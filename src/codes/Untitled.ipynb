# %%
using Jacobi

# %%
using PyPlot

x = linspace(-1,1, 401)
np = length(x)
Q = 5
z = zglj(Q)
h = zeros(np, Q)
for i = 1:Q
    for k = 1:np
        h[k,i] = lagrange(i, x[k], z)
    end
    plot(x, h[:,i])
    axvline(x=z[i], color="black")
end
axhline(y=0, color="black");
# Out:
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/PyPlot.ji for module PyPlot.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/URIParser.ji for module URIParser.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/Conda.ji for module Conda.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/BinDeps.ji for module BinDeps.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/Colors.ji for module Colors.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/FixedPointNumbers.ji for module FixedPointNumbers.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/ColorTypes.ji for module ColorTypes.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/Reexport.ji for module Reexport.
# INFO: Recompiling stale cache file /home/augusto/.julia/lib/v0.4/LaTeXStrings.ji for module LaTeXStrings.
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6c43092dd0>)
