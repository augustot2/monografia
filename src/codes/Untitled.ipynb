# %%
using Jacobi
using PyPlot

# %%
remap(x,a,b) = ((1-x).*a + (1+x).*b)/2
# Out:
# remap (generic function with 1 method)

# %%
fun(x) = (1-x)/2
# Out:
# fun (generic function with 1 method)

# %%
xx = linspace(-1,1,101)
plot(xx,[fun(x) for x in xx])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f516fe62a90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f516fc783d0>

# %%
Q =100
z = zglj(Q)
w = wglj(z)
integral = 0.0
for q in 1:Q
    integral += fun(z[q])*w[q]
end
integral
# Out:
# 1.0000000000000007

# %%
a= 0; b =5
integral = 0.0
for q in 1:Q
    integral += fun(z[q])*w[q]
end
integral*(b-a)/2
# Out:
# 2.5000000000000018

# %%
remap(-1,10,15)
# Out:
# 10.0
