# %%
using PyPlot
using Jacobi

# %%
Q = 19
x = linspace(-5,5,101)
f(x) = 1./(1+ x.^2)
z = 5*zglj(Q)
z2 = linspace(-5,5,Q)
imat2 = interp_mat(x,z2)
aprox2 = imat2* f(z2)
imat = interp_mat(x,z)
aprox = imat *  f(z)

plot(x,f(x), "-",color = "black")
plot(x,aprox,"--r")
plot(x,aprox2,"--b")

xlim(-5,5)
ylim(0,1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd090f6eb10>)
# (0,1)
