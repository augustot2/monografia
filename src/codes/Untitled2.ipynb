# %%
using Jacobi

# %%
ϕ₁(x, a, b)  = (b-x)/(b-a)
ϕ₂(x, a, b)  = (x-a)/(b-a)
mass_matrix(a, b) = [(b-a)/3 (b-a)/6; (b-a)/6 (b-a)/3]
# Out:
# mass_matrix (generic function with 1 method)

# %%
function ψj(p,E,Q)
    if(p == 1)
     return  (1-E)/2
        elseif(p == 2)
     return  (1+E)/2
    else
     return  (1-E)*(1+E)/4 .* jacobi(E, p-3, 1, 1)
    end
end
# Out:
# ψj (generic function with 1 method)

# %%
using PyPlot

# %%
x = [linspace(-1,1,101);]

for p in 1:5
    y = [ψj(p,x,0) for x in x]
    plot(y,label="L_$p")
end
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb5031e0b10>)
# PyObject <matplotlib.legend.Legend object at 0x7fb5033908d0>
